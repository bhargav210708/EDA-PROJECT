# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df["Region"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Total Revenue"].hist()
plt.show()

# %%
df.nsmallest(10, "Total Profit")

# %%
df.nlargest(10, "Total Profit")

# %%
df.sort_values("Total Revenue").head(10)

# %%
df.sort_values("Total Revenue", ascending=False).head(10)

# %%
df.groupby("Region")["Units Sold"].mean()df.groupby("Region")["Units Sold"].mean()

# %%
df.groupby("Region")["Total Revenue"].sum()

# %%
df.corr(numeric_only=True)

# %%
df.max(numeric_only=True)

# %%
df.median(numeric_only=True)

# %%
df.std(numeric_only=True)

# %%
df.mean(numeric_only=True)

# %%
df["Order Priority"].value_counts()

# %%
df["Sales Channel"].value_counts()

# %%
df["Country"].value_counts()

# %%
df["Region"].value_counts()

# %%
df.nunique()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.info()

# %%
df.dtypes

# %%
df.columns

# %%
df.shape[1]

# %%
df.shape[0]

# %%
df.shape

# %%
df.sample(5)

# %%
df.tail()

# %%
df.head()

# %%
df = pd.read_csv("../data/1000 Sales Records.csv")
df.head()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
